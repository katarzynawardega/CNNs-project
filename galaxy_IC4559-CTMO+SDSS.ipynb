# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import sep
import math
import keras
import numpy as np
from astropy.io import fits
from astropy.visualization import ZScaleInterval
from astropy import wcs
from astropy.wcs import WCS
from astropy.coordinates import SkyCoord

import random

import aplpy
from astroquery.sdss import SDSS
# Out:
# Using TensorFlow backend.

# %% [markdown]
# IMAGE FROM CTMO

# %%
hdu_ctmo = fits.open("/home/kasiawardega/Documents/thesis/kw_data/ic4559/stack-ctmo-ic4559.fit")

# %%
data_ctmo = hdu_ctmo[0].data

# %%
hdu_ctmo[0].header
# Out:
# SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    2 / Number of axes
# NAXIS1  =                 2048 / Axis length
# NAXIS2  =                 2048 / Axis length
# EXTEND  =                    F / File may contain extensions
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# DATE    = '2020-01-15T02:20:02' / Date FITS file was generated
# IRAF-TLM= '2020-01-15T02:20:01' / Time of last modification
# OBJECT  = 'ic4559  '           / Name of the object observed
# DATE-OBS= '2019-07-02T03:56:45' /YYYY-MM-DDThh:mm:ss observation start, UT
# EXPTIME =   300.00000000000000 /Exposure time in seconds
# EXPOSURE=   300.00000000000000 /Exposure time in seconds
# SET-TEMP=  0.00000000000000000 /CCD temperature setpoint in C
# CCD-TEMP= -2.200275000000E-002 /CCD temperature at start of exposure in C
# XPIXSZ  =   18.000000000000000 /Pixel Width in microns (after binning)
# YPIXSZ  =   18.000000000000000 /Pixel Height in microns (after binning)
# XBINNING=                    2 /Binning factor in width
# YBINNING=                    2 /Binning factor in height
# XORGSUBF=                    0 /Subframe X position in binned pixels
# YORGSUBF=                    0 /Subframe Y position in binned pixels
# READOUTM= 'Monochrome' /        Readout mode of image
# IMAGETYP= 'Light Frame' /       Type of image
# FOCALLEN= '2939    '           / Focal length of telescope in mm
# APTDIA  = '431.8   '           / Aperture diameter of telescope in mm
# APTAREA = '146574.1468'        / Aperture area of telescope in mm^2
# SBSTDVER= 'SBFITSEXT Version 1.0' /Version of SBFITSEXT standard in effect
# SWCREATE= 'MaxIm DL Version 6.20 190718 3263X' /Name of software
# SWSERIAL= '3263X-RJQES-8P8Y0-VT8US-VHY9P-8W' /Software serial number
# JD      =   2458666.6644097222 /Julian Date at start of exposure
# JD-HELIO=   2458666.6671406669 /Heliocentric Julian Date at exposure midpoint
# TELESCOP= 'CTMO    '           / telescope used to acquire this image
# INSTRUME= 'Apogee USB/Net'
# OBSERVER= 'Richard Camuccio'
# NOTES   = '        '
# FLIPSTAT= '        '
# SWOWNER = 'Aldo Fonrouge' /     Licensed owner of software
# FILTER  = 'unfiltered'
# COMMENT Original key: "END"
# COMMENT
# COMMENT --Start of Astrometry.net WCS solution--
# COMMENT --Put in by the new-wcs program--
# COMMENT
# WCSAXES =                    2 / no comment
# CTYPE1  = 'RA---TAN-SIP' / TAN (gnomic) projection + SIP distortions
# CTYPE2  = 'DEC--TAN-SIP' / TAN (gnomic) projection + SIP distortions
# EQUINOX =               2000.0 / Equatorial coordinates definition (yr)
# LONPOLE =                180.0 / no comment
# LATPOLE =                  0.0 / no comment
# CRVAL1  =        233.744595629 / RA  of reference point
# CRVAL2  =        25.6768449242 / DEC of reference point
# CRPIX1  =        1892.30703735 / X reference pixel
# CRPIX2  =        1726.45663452 / Y reference pixel
# CUNIT1  = 'deg     ' / X pixel scale units
# CUNIT2  = 'deg     ' / Y pixel scale units
# CD1_1   =    4.40673222206E-05 / Transformation matrix
# CD1_2   =   -0.000352039908262 / no comment
# CD2_1   =    0.000351961371855 / no comment
# CD2_2   =    4.39855220441E-05 / no comment
# IMAGEW  =                 2048 / Image width,  in pixels.
# IMAGEH  =                 2048 / Image height, in pixels.
# A_ORDER =                    2 / Polynomial order, axis 1
# A_0_0   =                    0 / no comment
# A_0_1   =                    0 / no comment
# A_0_2   =   -7.73803413655E-08 / no comment
# A_1_0   =                    0 / no comment
# A_1_1   =   -8.86755091527E-08 / no comment
# A_2_0   =   -2.85747511474E-07 / no comment
# B_ORDER =                    2 / Polynomial order, axis 2
# B_0_0   =                    0 / no comment
# B_0_1   =                    0 / no comment
# B_0_2   =   -2.03759658229E-07 / no comment
# B_1_0   =                    0 / no comment
# B_1_1   =   -1.48315714155E-07 / no comment
# B_2_0   =    2.09615398485E-08 / no comment
# AP_ORDER=                    2 / Inv polynomial order, axis 1
# AP_0_0  =   -3.93686393571E-05 / no comment
# AP_0_1  =   -1.77061041408E-07 / no comment
# AP_0_2  =    7.72187943615E-08 / no comment
# AP_1_0  =   -3.72309948698E-07 / no comment
# AP_1_1  =    8.83959091722E-08 / no comment
# AP_2_0  =    2.85267127106E-07 / no comment
# BP_ORDER=                    2 / Inv polynomial order, axis 2
# BP_0_0  =   -1.14862017322E-05 / no comment
# BP_0_1  =   -2.18760588897E-07 / no comment
# BP_0_2  =    2.03473419772E-07 / no comment
# BP_1_0  =   -5.15689635812E-08 / no comment
# BP_1_1  =    1.48084149018E-07 / no comment
# BP_2_0  =     -2.095882212E-08 / no comment
# HISTORY Created by the Astrometry.net suite.
# HISTORY For more details, see http://astrometry.net.
# HISTORY Git URL https://github.com/dstndstn/astrometry.net
# HISTORY Git revision 0.73
# HISTORY Git date Thu_Nov_16_08:30:44_2017_-0500
# HISTORY This WCS header was created by the program "blind".
# COMMENT -- blind solver parameters: --
# COMMENT Index(0): /usr/share/astrometry/index-4219.fits
# COMMENT Index(1): /usr/share/astrometry/index-4218.fits
# COMMENT Index(2): /usr/share/astrometry/index-4217.fits
# COMMENT Index(3): /usr/share/astrometry/index-4216.fits
# COMMENT Index(4): /usr/share/astrometry/index-4215.fits
# COMMENT Index(5): /usr/share/astrometry/index-4214.fits
# COMMENT Index(6): /usr/share/astrometry/index-4213.fits
# COMMENT Index(7): /usr/share/astrometry/index-4212.fits
# COMMENT Index(8): /usr/share/astrometry/index-4211.fits
# COMMENT Index(9): /usr/share/astrometry/index-4210.fits
# COMMENT Index(10): /usr/share/astrometry/index-4209.fits
# COMMENT Index(11): /usr/share/astrometry/index-4208.fits
# COMMENT Index(12): /usr/share/astrometry/index-4207-02.fits
# COMMENT Index(13): /usr/share/astrometry/index-4206-02.fits
# COMMENT Index(14): /usr/share/astrometry/index-4205-02.fits
# COMMENT Index(15): /usr/share/astrometry/index-4204-08.fits
# COMMENT Index(16): /usr/share/astrometry/index-4203-08.fits
# COMMENT Index(17): /usr/share/astrometry/index-4202-08.fits
# COMMENT Index(18): /usr/share/astrometry/index-4201-08.fits
# COMMENT Index(19): /usr/share/astrometry/index-4200-08.fits
# COMMENT Index(20): /usr/share/astrometry/index-4119.fits
# COMMENT Index(21): /usr/share/astrometry/index-4118.fits
# COMMENT Index(22): /usr/share/astrometry/index-4117.fits
# COMMENT Index(23): /usr/share/astrometry/index-4116.fits
# COMMENT Index(24): /usr/share/astrometry/index-4115.fits
# COMMENT Index(25): /usr/share/astrometry/index-4114.fits
# COMMENT Index(26): /usr/share/astrometry/index-4113.fits
# COMMENT Index(27): /usr/share/astrometry/index-4112.fits
# COMMENT Index(28): /usr/share/astrometry/index-4111.fits
# COMMENT Index(29): /usr/share/astrometry/index-4110.fits
# COMMENT Index(30): /usr/share/astrometry/index-4109.fits
# COMMENT Index(31): /usr/share/astrometry/index-4108.fits
# COMMENT Index(32): /usr/share/astrometry/index-4107.fits
# COMMENT Field name: ./mesh-ic4559-0001.axy
# COMMENT Field scale lower: 0.175781 arcsec/pixel
# COMMENT Field scale upper: 316.406 arcsec/pixel
# COMMENT X col name: X
# COMMENT Y col name: Y
# COMMENT Start obj: 20
# COMMENT End obj: 30
# COMMENT Solved_in: (null)
# COMMENT Solved_out: ./mesh-ic4559-0001.solved
# COMMENT Solvedserver: (null)
# COMMENT Parity: 2
# COMMENT Codetol: 0.01
# COMMENT Verify pixels: 1 pix
# COMMENT Maxquads: 0
# COMMENT Maxmatches: 0
# COMMENT Cpu limit: 300.000000 s
# COMMENT Time limit: 0 s
# COMMENT Total time limit: 0 s
# COMMENT Total CPU limit: 300.000000 s
# COMMENT Tweak: yes
# COMMENT Tweak AB order: 2
# COMMENT Tweak ABP order: 2
# COMMENT --
# COMMENT -- properties of the matching quad: --
# COMMENT index id: 4203
# COMMENT index healpix: 8
# COMMENT index hpnside: 2
# COMMENT log odds: 1852.3
# COMMENT odds: inf
# COMMENT quadno: 386835
# COMMENT stars: 660529,660489,660525,660487
# COMMENT field: 27,0,9,18
# COMMENT code error: 0.00388654
# COMMENT nmatch: 573
# COMMENT nconflict: 97
# COMMENT nfield: 1868
# COMMENT nindex: 588
# COMMENT scale: 1.27708 arcsec/pix
# COMMENT parity: 1
# COMMENT quads tried: 7501
# COMMENT quads matched: 1821
# COMMENT quads verified: 6
# COMMENT objs tried: 28
# COMMENT cpu time: 0.048493
# COMMENT --
# COMMENT
# COMMENT --End of Astrometry.net WCS--
# COMMENT --(Put in by the new-wcs program)--
# COMMENT
# IMCMB001= 'a-wcs-mesh-ic4559-0001.fit'
# IMCMB002= 'a-wcs-mesh-ic4559-0002.fit'
# IMCMB003= 'a-wcs-mesh-ic4559-0003.fit'
# IMCMB004= 'a-wcs-mesh-ic4559-0004.fit'
# IMCMB005= 'a-wcs-mesh-ic4559-0005.fit'
# NCOMBINE=                    5

# %%
interval = ZScaleInterval()
vmin, vmax = interval.get_limits(data_ctmo)

plt.imshow(data_ctmo, vmin=vmin, vmax=vmax, origin='lower',cmap='gray')
plt.imsave('image_ctmo.png', data_ctmo, vmin=vmin, vmax=vmax, origin='lower',cmap='gray')

# %% [markdown]
# IMAGE FROM SDSS

# %%
from astroquery.skyview import SkyView
from astropy import coordinates as coords
from astropy.coordinates import SkyCoord
import astropy.units as u

#frame_coord = SkyCoord(ra=center_ra * u.deg, dec=center_dec * u.deg).icrs
fov_radius = 50 * u.arcmin
pos = coords.SkyCoord('15h35m53.5178382775s +25d20m28.078077492s', frame='icrs')

hdu_sdss = SkyView.get_images(position=pos, coordinates='icrs', pixels=2000,
                         survey='SDSSg', radius=fov_radius)[0]

# %%
hdu_sdss[0].header
# Out:
# SIMPLE  =                    T / Written by SkyView Thu Jan 16 15:12:12 EST 2020
# BITPIX  =                  -32 / 4 byte floating point
# NAXIS   =                    2 / Two dimensional image
# NAXIS1  =                 2000 / Width of image
# NAXIS2  =                 2000 / Height of image
# CRVAL1  =              233.973 / Reference longitude
# CRVAL2  =              25.3411 / Reference latitude
# RADESYS = 'FK5     '           / Coordinate system
# EQUINOX =                 2000 / ICRS coordinates
# CTYPE1  = 'RA---TAN'           / Coordinates -- projection
# CTYPE2  = 'DEC--TAN'           / Coordinates -- projection
# CRPIX1  =               1000.5 / X reference pixel
# CRPIX2  =               1000.5 / Y reference pixel
# CDELT1  = -0.00041666666666666664 / X scale
# CDELT2  = 0.00041666666666666664 / Y scale
# COMMENT
# COMMENT SkyView Survey metadata
# COMMENT
# COMMENT Provenance:  Sloan Digital Sky Survey Team
# COMMENT Copyright:   See        Sloan usage document for distribution rights a
# COMMENT          nd acknowledgements.
# COMMENT Regime:      Optical
# COMMENT NSurvey:     5
# COMMENT Frequency:   646 THz
# COMMENT Bandpass:    567-750 THz
# COMMENT Coverage:    14,555 square degrees. The SDDS site provides coverage ma
# COMMENT          ps
# COMMENT PixelScale:  0.4"
# COMMENT PixelUnits:
# COMMENT Resolution:  1"
# COMMENT Coordinates: Equatorial
# COMMENT Projection:  Tangent
# COMMENT Epoch:       1998 to 2011
# COMMENT Reference:    Sloan Digital Sky Survey web site    or   ADS
# COMMENT
# COMMENT Survey specific cards
# COMMENT
# SURVEY  = 'SDSS-g  '
# COMMENT From release DR9
# COMMENT These data are resampled from the Sloan Digital Sky Survey Data
# COMMENT available at www.sdss3.org.
# COMMENT Image datasets were dynamically downloaded from the Sloan Site
# COMMENT and resampled into the projection requested by the user.
# HISTORY
# HISTORY Settings used in processing:
# HISTORY
# HISTORY cache = /data/cache/surveys/
# HISTORY catalogids = on
# HISTORY coordinates = ICRS
# HISTORY descriptionxslt = cgifiles/description.xsl
# HISTORY dft_cache = ./skycache/
# HISTORY dummy
# HISTORY equinox = 2000
# HISTORY finalpostprocessor = skyview.ij.IJProcessor,skyview.data.BoxSmoother,sky
# HISTORY float = on
# HISTORY footertemplate = cgifiles/skyfooter.html
# HISTORY gallerydir = /userimages
# HISTORY galleryxslt = cgifiles/gallerymultipage.xsl
# HISTORY gridlabels = 0
# HISTORY headertemplate = cgifiles/skyheader.html
# HISTORY htmlwriter = skyview.request.HTMLWriter
# HISTORY imagefactory = skyview.survey.CachingImageFactory
# HISTORY imagefinder = LocalBorder
# HISTORY imagesize = 0.25
# HISTORY imscale = 0.8333333333333334
# HISTORY localurl = https://skyview.gsfc.nasa.gov/surveys,/skyview/htdocs/surveys
# HISTORY lut = colortables/b-w-linear.bin
# HISTORY lutcbarpath = ../images/colorbars/
# HISTORY mosaicker = skyview.process.Mosaicker
# HISTORY name = Sloan Digital Sky Survey g-band
# HISTORY noexit =
# HISTORY nullimagedir = ../images/nodata
# HISTORY output = ../../tempspace/fits/skv8060851282527
# HISTORY outputroot = ../../tempspace/fits
# HISTORY pixels = 2000
# HISTORY position = 233.973 25.3411
# HISTORY postprocessor = skyview.ij.IJProcessor,skyview.request.HTMLWriter
# HISTORY projection = Tan
# HISTORY quicklook = jpeg
# HISTORY reqxpos = 233.973
# HISTORY reqypos = 25.3411
# HISTORY resolver = SIMBAD-NED
# HISTORY rgbtemplate = cgifiles/skyrgb.html
# HISTORY rgbwriter = skyview.request.RGBWriter
# HISTORY sampler = Default
# HISTORY savebysurvey
# HISTORY scale = 0.00011
# HISTORY scaling = Log Sqrt Linear HistEq LogLog
# HISTORY settingsupdaters = BatchCompatibility,SettingsFixer,skyview.request.Toas
# HISTORY shortname = SDSSg,SDSS g
# HISTORY sia_header = ./sia.header
# HISTORY siabase = https://skyview.gsfc.nasa.gov/cgi-bin/images?
# HISTORY siaimagetimeout = 300000
# HISTORY siapcoordinates = J2000
# HISTORY siapprojection = Tan
# HISTORY siapurl = http://skyserver.sdss.org/vo/DR8SIAP/SIAP.asmx/getSiapInfo?FOR
# HISTORY siapurltransform = http://data.sdss3.org,https://data.sdss.org
# HISTORY size = 0.8333333333333334,0.8333333333333334
# HISTORY survey = SDSSg
# HISTORY surveyfinder = skyview.survey.XMLSurveyFinder
# HISTORY surveymanifest = surveys/survey.manifest
# HISTORY surveyregimes = Radio,Millimeter,Infrared,Optical,Ultraviolet,X-ray,Gamm
# HISTORY surveysheader = cgifiles/survey.header
# HISTORY surveytemplate = cgifiles/skysurvey.html
# HISTORY url.heasarcbase = https://heasarc.gsfc.nasa.gov/xamin/vo/cone?showoffset
# HISTORY url.ned = http://nedwww.ipac.caltech.edu/cgi-bin/nph-NEDobjsearch?search
# HISTORY url.simbad = http://simbad.u-strasbg.fr/simbad-conesearch.pl?
# HISTORY url.vizierbase = http://vizier.u-strasbg.fr/viz-bin/votable/-dtd/-A?-out
# HISTORY urllocalhelp = https://skyview.gsfc.nasa.gov/help/help.html
# HISTORY version = 3.5.1
# HISTORY webrootpath = /skyview/htdocs
# HISTORY xmlurlprefix = https://skyview.gsfc.nasa.gov/current/jar/
# HISTORY
# HISTORY Map generated at: Thu Jan 16 15:12:12 EST 2020
# HISTORY
# HISTORY Resampler used: NNSampler
# HISTORY
# HISTORY
# HISTORY Image mosaicking usingskyview.process.Mosaicker
# HISTORY
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004540-4-0015.fits.bz2
# HISTORY       Pixels:89588
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004570-4-0172.fits.bz2
# HISTORY       Pixels:9462
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004576-4-0736.fits.bz2
# HISTORY       Pixels:19649
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004540-4-0018.fits.bz2
# HISTORY       Pixels:55437
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004014-1-0190.fits.bz2
# HISTORY       Pixels:50559
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004010-1-0142.fits.bz2
# HISTORY       Pixels:90460
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004576-4-0733.fits.bz2
# HISTORY       Pixels:2866
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004570-5-0171.fits.bz2
# HISTORY       Pixels:32440
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004570-4-0169.fits.bz2
# HISTORY       Pixels:92009
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004010-1-0145.fits.bz2
# HISTORY       Pixels:13298
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004014-1-0187.fits.bz2
# HISTORY       Pixels:7882
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004576-6-0735.fits.bz2
# HISTORY       Pixels:89415
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004512-1-0235.fits.bz2
# HISTORY       Pixels:40703
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004540-5-0018.fits.bz2
# HISTORY       Pixels:12682
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004576-5-0739.fits.bz2
# HISTORY       Pixels:16771
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004570-5-0169.fits.bz2
# HISTORY       Pixels:31118
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004576-6-0734.fits.bz2
# HISTORY       Pixels:52071
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004010-1-0138.fits.bz2
# HISTORY       Pixels:11396
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004570-6-0170.fits.bz2
# HISTORY       Pixels:14682
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004010-1-0144.fits.bz2
# HISTORY       Pixels:90514
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004570-4-0168.fits.bz2
# HISTORY       Pixels:92002
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004540-5-0015.fits.bz2
# HISTORY       Pixels:59008
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004576-5-0733.fits.bz2
# HISTORY       Pixels:155275
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004540-4-0019.fits.bz2
# HISTORY       Pixels:5753
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004512-1-0232.fits.bz2
# HISTORY       Pixels:32797
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004540-6-0016.fits.bz2
# HISTORY       Pixels:4917
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004540-5-0014.fits.bz2
# HISTORY       Pixels:59723
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004512-1-0237.fits.bz2
# HISTORY       Pixels:5835
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004576-5-0732.fits.bz2
# HISTORY       Pixels:22210
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004576-5-0738.fits.bz2
# HISTORY       Pixels:148035
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004570-5-0168.fits.bz2
# HISTORY       Pixels:30395
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004540-4-0013.fits.bz2
# HISTORY       Pixels:48523
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004014-1-0192.fits.bz2
# HISTORY       Pixels:11122
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004570-4-0167.fits.bz2
# HISTORY       Pixels:71914
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004010-1-0143.fits.bz2
# HISTORY       Pixels:90448
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004512-1-0236.fits.bz2
# HISTORY       Pixels:40909
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004540-5-0013.fits.bz2
# HISTORY       Pixels:60534
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004512-1-0233.fits.bz2
# HISTORY       Pixels:40411
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004014-1-0188.fits.bz2
# HISTORY       Pixels:34238
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004576-5-0734.fits.bz2
# HISTORY       Pixels:157691
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004576-6-0733.fits.bz2
# HISTORY       Pixels:18958
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004540-5-0016.fits.bz2
# HISTORY       Pixels:58280
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004576-5-0737.fits.bz2
# HISTORY       Pixels:151895
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004570-5-0167.fits.bz2
# HISTORY       Pixels:29552
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004010-2-0143.fits.bz2
# HISTORY       Pixels:65903
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004540-4-0014.fits.bz2
# HISTORY       Pixels:89569
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004014-1-0191.fits.bz2
# HISTORY       Pixels:50348
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004576-4-0735.fits.bz2
# HISTORY       Pixels:80343
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004570-5-0170.fits.bz2
# HISTORY       Pixels:31821
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004540-4-0017.fits.bz2
# HISTORY       Pixels:85603
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004570-5-0166.fits.bz2
# HISTORY       Pixels:26025
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004010-2-0142.fits.bz2
# HISTORY       Pixels:40509
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004576-6-0737.fits.bz2
# HISTORY       Pixels:62083
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004014-1-0189.fits.bz2
# HISTORY       Pixels:50765
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004576-5-0736.fits.bz2
# HISTORY       Pixels:153843
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004570-5-0172.fits.bz2
# HISTORY       Pixels:5425
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004570-4-0171.fits.bz2
# HISTORY       Pixels:41256
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004010-1-0141.fits.bz2
# HISTORY       Pixels:90421
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004540-5-0012.fits.bz2
# HISTORY       Pixels:58941
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004010-1-0140.fits.bz2
# HISTORY       Pixels:90449
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004540-5-0017.fits.bz2
# HISTORY       Pixels:57639
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004010-1-0139.fits.bz2
# HISTORY       Pixels:86991
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004570-4-0170.fits.bz2
# HISTORY       Pixels:87424
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004576-4-0734.fits.bz2
# HISTORY       Pixels:115206
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004540-4-0016.fits.bz2
# HISTORY       Pixels:89587
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004576-6-0736.fits.bz2
# HISTORY       Pixels:90210
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004512-1-0234.fits.bz2
# HISTORY       Pixels:40474
# HISTORY  Used image:/data/cache/surveys/SDSSg/frame-g-004576-5-0735.fits.bz2
# HISTORY       Pixels:155738
# HISTORY

# %%
data_sdss = hdu_sdss[0].data

# %%
interval = ZScaleInterval()
vmin, vmax = interval.get_limits(data_sdss)
plt.imshow(data_sdss, vmin=vmin, vmax=vmax, origin='lower',cmap='gray')
plt.imsave('image_sdss.png', data_sdss, vmin=vmin, vmax=vmax, origin='lower',cmap='gray')

# %% [markdown]
# ALIGNING IMAGES

# %%
from reproject import reproject_interp
data_sdss_fitted, footprint = reproject_interp(hdu_sdss[0], hdu_ctmo[0].header)

# %%
interval = ZScaleInterval()
vmin, vmax = interval.get_limits(data_sdss_fitted)
plt.imshow(data_sdss_fitted, vmin=vmin, vmax=vmax, origin='lower',cmap='gray')
plt.imsave('image_sdss_fitted.png', data_sdss_fitted, vmin=vmin, vmax=vmax, origin='lower',cmap='gray')

# %% [markdown]
# OBJECT DETECTION - CTMO IMAGE

# %%
bkg = sep.Background(data_ctmo.astype("f8"),bw=128, bh=128, fw=3, fh=3)
sigma = bkg.globalrms

data_ctmo = data_ctmo.byteswap().newbyteorder()

objects = sep.extract(data_ctmo, 3*sigma, err=bkg.globalrms)

# %%
len(objects)
# Out:
# 321

# %%
from matplotlib.patches import Ellipse

# plot background-subtracted image
fig, ax = plt.subplots()
m, s = np.mean(data_ctmo), np.std(data_ctmo)
im = ax.imshow(data_ctmo, interpolation='nearest', cmap='gray',
               vmin=m-s, vmax=m+s, origin='lower')

# plot an ellipse for each object
for i in range(len(objects)):
    e = Ellipse(xy=(objects['x'][i], objects['y'][i]),
                width=6*objects['a'][i],
                height=6*objects['b'][i],
                angle=objects['theta'][i] * 180. / np.pi)
    e.set_facecolor('none')
    e.set_edgecolor('red')
    ax.add_artist(e)

# %%
np.round(objects['x']).shape
# Out:
# (321,)

# %%
objects_coord = []

for i in range (0,len(objects)):
    objects_coord.append([objects['x'][i], objects['y'][i]])
    
objects_coord = np.array(objects_coord)

# %%
objects_coord.shape[0]
# Out:
# 321

# %% [markdown]
#     CREATING DATASETS

# %%
def cut_object(im, x,y,l):
    x = int(round(x))
    y = int(round(y))
    
    return im[y-l:y+l+1, x-l:x+l+1]

# %%
def creating_dataset (im, coord):
    
    images = []
    for i in range (0,coord.shape[0]):
        
        if (coord[i][0] < im.shape[1]-21 and coord[i][1] < im.shape[0]-21):
            images.append(cut_object(im, coord[i][0], coord[i][1],10))
            #images[i,:,:] = cut_object(im, objects['x'][i], objects['y'][i],10)
            
    images = np.array(images)
    return images

# %%
def creating_transient (im, coord):
    
    images  = []    
    
    for i in range (0,coord.shape[0]):
        x = random.randint(21,im.shape[1]-21)
        y = random.randint(21,im.shape[0]-21)
                
        while not checkAwayFromStars(x, np.round(objects_coord[:,0])):
             x = random.randint(21,im.shape[1]-21)
        
        while not checkAwayFromStars(y, np.round(objects_coord[:,0])):
             y = random.randint(21,im.shape[1]-21)
        #while x in np.round(coord[:,0]):
            #x = random.randint(21,im.shape[1]-21)
            
        #while y in np.round(coord[:,1]):
            #y = random.randint(21,im.shape[0]-21)
                   
        if (coord[i][0] < im.shape[1]-21 and coord[i][1] < im.shape[0]-21):
            images.append(cut_object(im, x, y,10))
            
    images = np.array(images)
    return images

# %%
def checkAwayFromStars(point, stars, minDist = 10):
    "Check that point is at at least minDist from any other position in stars iterable."
    for p in stars:
        if np.linalg.norm(point - p) < minDist:
            return False
    return True

# %%
transient_sample = creating_transient(data_sdss_fitted, objects_coord)

# %%
transient_sample.shape
# Out:
# (320, 21, 21)

# %%
#examples of background

for i in range(0,100,2):
    f = plt.figure(figsize=(10,3))
    ax = f.add_subplot(121)
    ax2 = f.add_subplot(122)    
    ax.imshow(transient_sample[i,:,:])
    ax2.imshow(transient_sample[i+1,:,:])
# Out:
# /home/kasiawardega/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
dataset_ctmo = creating_dataset(data_ctmo, objects_coord)

# %%
dataset_ctmo.shape
# Out:
# (320, 21, 21)

# %%
dataset_sdss = creating_dataset(data_sdss_fitted, objects_coord)

# %%
dataset_sdss.shape
# Out:
# (320, 21, 21)

# %%
dataset_ic4559_nontran = np.zeros((dataset_ctmo.shape[0],21,21,2))
dataset_ic4559_tran = np.ones((dataset_ctmo.shape[0],21,21,2))

# %%
labels_ic4559_nontran = np.zeros(dataset_ctmo.shape[0])
labels_ic4559_tran = np.ones(dataset_ctmo.shape[0])

# %%
dataset_ic4559_nontran[:,:,:,0] = dataset_ctmo
dataset_ic4559_nontran[:,:,:,1] = dataset_sdss

dataset_ic4559_tran[:,:,:,0] = dataset_ctmo
dataset_ic4559_tran[:,:,:,1] = transient_sample

# %%
#NONTRANSIENT SAMPLES

for i in range(100):
    f = plt.figure(figsize=(10,3))
    ax = f.add_subplot(121)
    ax2 = f.add_subplot(122)    
    ax.imshow(dataset_ic4559_nontran[i,:,:,0])
    ax2.imshow(dataset_ic4559_nontran[i,:,:,1])
# Out:
# /home/kasiawardega/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.

# %%
#TRANSIENT SAMPLES

for i in range(100):
    f = plt.figure(figsize=(10,3))
    ax = f.add_subplot(121)
    ax2 = f.add_subplot(122)    
    ax.imshow(dataset_ic4559_tran[i,:,:,0])
    ax2.imshow(dataset_ic4559_tran[i,:,:,1])
# Out:
# /home/kasiawardega/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.

# %%
#MERGING TRANSIENT AND NONTRANSIENT SAMPLES

def merging_datasets(nontr, tr):
    
           
    dataset = np.append(nontr, tr, axis=0)
    
    labels = np.zeros(dataset.shape[0])
    labels[320:dataset.shape[0]] = 1

    return dataset, labels

# %%
merge_dataset, labels = merging_datasets(dataset_ic4559_nontran,dataset_ic4559_tran)

# %%
merge_dataset.shape
# Out:
# (640, 21, 21, 2)

# %%
f = plt.figure(figsize=(10,3))
ax = f.add_subplot(121)
ax2 = f.add_subplot(122)    
ax.imshow(merge_data[100,:,:,0])
ax2.imshow(merge_data[100,:,:,1])

f = plt.figure(figsize=(10,3))
ax = f.add_subplot(121)
ax2 = f.add_subplot(122)    
ax.imshow(merge_data[500,:,:,0])
ax2.imshow(merge_data[500,:,:,1])

# %%
np.save('galaxy_ic4559_images.npy', merge_dataset)
np.save('galaxy_ic4559_labels.npy', labels)

# %%
plt.imshow(dataset_ic4559[132,:,:,0])
plt.imsave('ctmo_image132.png', dataset_ic4559[132,:,:,0])
